# %%
import datetime, warnings, scipy 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from datetime import date
from matplotlib.patches import ConnectionPatch
from collections import OrderedDict
from matplotlib.gridspec import GridSpec
from mpl_toolkits.basemap import Basemap
from sklearn import metrics, linear_model
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from scipy.optimize import curve_fit
plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.options.display.max_columns = 50
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Data Descriptions and Details
# __YEAR, MONTH, DAY, DAY_OF_WEEK__: dates of the flight <br>
# __AIRLINE__: An identification number assigned by US DOT to identify a unique airline<br>
# __ORIGIN_AIRPORT and DESTINATION_AIRPORT__: code attributed by IATA to identify the airports<br>
# __SCHEDULED_DEPARTURE and SCHEDULED_ARRIVAL__ : scheduled times of take-off and landing<br>
# __DEPARTURE_TIME and ARRIVAL_TIME__: real times at which take-off and landing took place<br>
# __DEPARTURE_DELAY and ARRIVAL_DELAY__: difference (in minutes) between planned and real times<br>
# __DISTANCE__: distance (in miles)<br>
# __TAXI_IN__:The time duration elapsed between wheels-on and gate arrival at the destination airport
# __TAXI_OUT__: The time duration elapsed between departure from the origin airport gate and wheels off<br>
# __WHEELS_ON__:The time point that the aircraft's wheels touch on the ground<br>
# __WHEELS_OFF__: The time point that the aircraft's wheels leave the ground<br>
# __AIR_TIME__:The time duration between wheels_off and wheels_on time<br>
# __ELAPSED_TIME__:AIR_TIME+TAXI_IN+TAXI_OUT<br>
# __DISTANCE__:Distance between two airports<br>
# __SCHEDULED_TIME__:Planned time amount needed for the flight trip<br>

# %%
# df = pd.read_csv('./flight-delays/flights.csv', low_memory=False)
# df.head(10)

# %%
# df.shape

# %% [markdown]
# There are 5,8 millions data which will be too slow for the training and ploting the data. Thus, for this project I will only use partial of the data which taken randomly

# %%
# dfFlights = df.sample(frac=0.05)

# %%
# dfFlights.shape

# %% [markdown]
# dfFlights.to_csv('Flights_sample.csv',index=False)

# %%
dfFlights = pd.read_csv('Flights_sample.csv')
pd.get_option("display.max_columns")
# Out:
# 50

# %%
dfFlights.shape
# Out:
# (290954, 31)

# %%
def table_data(df):
    data=[]
    n=2
    for item in df.columns:
        if df[item].nunique()==1:
            n=1
        else:
            n=2
        data.append([
                    item,
                    df.dtypes.loc[item],
                    df[item].isna().sum(),
                    df[item].isna().sum()/len(df[item])*100,
                    df[item].nunique(),
                    list(df[df[item].notnull()].drop_duplicates(subset=item)[item].sample(n=n))
                    ])

    df_info = pd.DataFrame(data=data, columns=['dataFeatures', 'dataType','null','nullPct','unique','sample'])
    return df_info

# %%
df_info = table_data(dfFlights)

# %%
df_info
# Out:
#            dataFeatures dataType    null    nullPct  unique            sample
# 0                  YEAR    int64       0   0.000000       1            [2015]
# 1                 MONTH    int64       0   0.000000      12           [10, 9]
# 2                   DAY    int64       0   0.000000      31          [21, 27]
# 3           DAY_OF_WEEK    int64       0   0.000000       7            [3, 4]
# 4               AIRLINE   object       0   0.000000      14          [MQ, HA]
# 5         FLIGHT_NUMBER    int64       0   0.000000    6588      [7395, 5590]
# 6           TAIL_NUMBER   object     761   0.261553    4754  [N770UW, N3BVAA]
# 7        ORIGIN_AIRPORT   object       0   0.000000     618      [13796, IAG]
# 8   DESTINATION_AIRPORT   object       0   0.000000     621        [ORD, TYR]
# 9   SCHEDULED_DEPARTURE    int64       0   0.000000    1256      [1314, 1800]
# 10       DEPARTURE_TIME  float64    4445   1.527733    1386  [1821.0, 2224.0]
# 11      DEPARTURE_DELAY  float64    4445   1.527733     595    [347.0, 516.0]
# 12             TAXI_OUT  float64    4619   1.587536     152     [40.0, 147.0]
# 13           WHEELS_OFF  float64    4619   1.587536    1384  [1755.0, 1038.0]
# 14       SCHEDULED_TIME  float64       0   0.000000     514    [535.0, 645.0]
# 15         ELAPSED_TIME  float64    5445   1.871430     589    [652.0, 451.0]
# 16             AIR_TIME  float64    5445   1.871430     572     [351.0, 21.0]
# 17             DISTANCE    int64       0   0.000000    1322       [394, 2611]
# 18            WHEELS_ON  float64    4789   1.645965    1436   [2050.0, 610.0]
# 19              TAXI_IN  float64    4789   1.645965     125       [40.0, 7.0]
# 20    SCHEDULED_ARRIVAL    int64       0   0.000000    1372        [953, 123]
# 21         ARRIVAL_TIME  float64    4789   1.645965    1438   [1716.0, 508.0]
# 22        ARRIVAL_DELAY  float64    5445   1.871430     621     [-7.0, 430.0]
# 23             DIVERTED    int64       0   0.000000       2            [0, 1]
# 24            CANCELLED    int64       0   0.000000       2            [1, 0]
# 25  CANCELLATION_REASON   object  286292  98.397685       3            [C, A]
# 26     AIR_SYSTEM_DELAY  float64  237870  81.755192     308     [119.0, 87.0]
# 27       SECURITY_DELAY  float64  237870  81.755192      54      [54.0, 99.0]
# 28        AIRLINE_DELAY  float64  237870  81.755192     456    [241.0, 742.0]
# 29  LATE_AIRCRAFT_DELAY  float64  237870  81.755192     367     [114.0, 41.0]
# 30        WEATHER_DELAY  float64  237870  81.755192     267     [45.0, 157.0]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ['CANCELLATION_REASON','AIR_SYSTEM_DELAY',
# 'SECURITY_DELAY','AIRLINE_DELAY','LATE_AIRCRAFT_DELAY','WEATHER_DELAY'] These Collums have >80% of null value, so These collumns will be dropped. As for the other nulll values which is less than 1% and the dataset provide good amount of data, so those row with the null values will also be dropped. Also some of unimportant feature such as Flight number and tail number

# %%
variables_to_remove = [ 'AIR_SYSTEM_DELAY','SECURITY_DELAY', 'AIRLINE_DELAY'
                       ,'LATE_AIRCRAFT_DELAY','WEATHER_DELAY', 'DIVERTED',
                       'CANCELLED', 'CANCELLATION_REASON',
                       'FLIGHT_NUMBER', 'TAIL_NUMBER']
df = dfFlights.drop(variables_to_remove, axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290954 entries, 0 to 290953
# Data columns (total 21 columns):
# YEAR                   290954 non-null int64
# MONTH                  290954 non-null int64
# DAY                    290954 non-null int64
# DAY_OF_WEEK            290954 non-null int64
# AIRLINE                290954 non-null object
# ORIGIN_AIRPORT         290954 non-null object
# DESTINATION_AIRPORT    290954 non-null object
# SCHEDULED_DEPARTURE    290954 non-null int64
# DEPARTURE_TIME         286509 non-null float64
# DEPARTURE_DELAY        286509 non-null float64
# TAXI_OUT               286335 non-null float64
# WHEELS_OFF             286335 non-null float64
# SCHEDULED_TIME         290954 non-null float64
# ELAPSED_TIME           285509 non-null float64
# AIR_TIME               285509 non-null float64
# DISTANCE               290954 non-null int64
# WHEELS_ON              286165 non-null float64
# TAXI_IN                286165 non-null float64
# SCHEDULED_ARRIVAL      290954 non-null int64
# ARRIVAL_TIME           286165 non-null float64
# ARRIVAL_DELAY          285509 non-null float64
# dtypes: float64(11), int64(7), object(3)
# memory usage: 46.6+ MB

# %%
df.dropna(inplace=True)

# %%
df_info = table_data(df)
df_info
# Out:
#            dataFeatures dataType  null  nullPct  unique            sample
# 0                  YEAR    int64     0      0.0       1            [2015]
# 1                 MONTH    int64     0      0.0      12           [1, 11]
# 2                   DAY    int64     0      0.0      31           [9, 30]
# 3           DAY_OF_WEEK    int64     0      0.0       7            [2, 6]
# 4               AIRLINE   object     0      0.0      14          [OO, DL]
# 5        ORIGIN_AIRPORT   object     0      0.0     617        [CIU, SJT]
# 6   DESTINATION_AIRPORT   object     0      0.0     621      [13029, MYR]
# 7   SCHEDULED_DEPARTURE    int64     0      0.0    1256        [41, 1656]
# 8        DEPARTURE_TIME  float64     0      0.0    1385     [927.0, 41.0]
# 9       DEPARTURE_DELAY  float64     0      0.0     591    [361.0, 501.0]
# 10             TAXI_OUT  float64     0      0.0     151     [146.0, 67.0]
# 11           WHEELS_OFF  float64     0      0.0    1384  [1700.0, 2050.0]
# 12       SCHEDULED_TIME  float64     0      0.0     514     [251.0, 79.0]
# 13         ELAPSED_TIME  float64     0      0.0     589    [164.0, 104.0]
# 14             AIR_TIME  float64     0      0.0     572     [420.0, 18.0]
# 15             DISTANCE    int64     0      0.0    1321       [431, 1533]
# 16            WHEELS_ON  float64     0      0.0    1436    [736.0, 400.0]
# 17              TAXI_IN  float64     0      0.0     125      [63.0, 80.0]
# 18    SCHEDULED_ARRIVAL    int64     0      0.0    1372      [1239, 1831]
# 19         ARRIVAL_TIME  float64     0      0.0    1438   [424.0, 2039.0]
# 20        ARRIVAL_DELAY  float64     0      0.0     621      [-6.0, 36.0]

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0  2015      4    4            6      UA            FLL                 CLE
# 1  2015      6   22            1      WN            PHX                 LAX
# 2  2015     12   27            7      DL            SAN                 DTW
# 3  2015      5   21            4      WN            MKE                 RSW
# 4  2015      7    5            7      WN            MDW                 CLE
#
#    SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  \
# 0                 1104          1059.0             -5.0      13.0      1112.0
# 1                  900          1018.0             78.0      14.0      1032.0
# 2                 1135          1129.0             -6.0      29.0      1158.0
# 3                  605           558.0             -7.0      17.0       615.0
# 4                 2215          2213.0             -2.0      14.0      2227.0
#
#    SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# 0           176.0         171.0     149.0      1062     1341.0      9.0
# 1            90.0          75.0      53.0       370     1125.0      8.0
# 2           264.0         264.0     229.0      1956     1847.0      6.0
# 3           175.0         172.0     151.0      1183      946.0      4.0
# 4            65.0          71.0      50.0       307       17.0      7.0
#
#    SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY
# 0               1400        1350.0          -10.0
# 1               1030        1133.0           63.0
# 2               1859        1853.0           -6.0
# 3               1000         950.0          -10.0
# 4                 20          24.0            4.0

# %% [markdown]
# ___To make the data cleaner, the YEAR,MONTH,DAY, and other time relative columns are transformed into datetime python library format___

# %%
df['DATE'] = pd.to_datetime(df[['YEAR','MONTH', 'DAY']])

# %%
#_________________________________________________________
# Function that convert the 'HHMM' string to datetime.time
def format_heure(chaine):
    if pd.isnull(chaine):
        return np.nan
    else:
        if chaine == 2400: chaine = 0
        chaine = "{0:04d}".format(int(chaine))
        heure = datetime.time(int(chaine[0:2]), int(chaine[2:4]))
        return heure
#_____________________________________________________________________
# Function that combines a date and time to produce a datetime.datetime
def combine_date_heure(x):
    if pd.isnull(x[0]) or pd.isnull(x[1]):
        return np.nan
    else:
        return datetime.datetime.combine(x[0],x[1])
#_______________________________________________________________________________
# Function that combine two columns of the dataframe to create a datetime format
def create_flight_time(df, col):    
    liste = []
    for index, cols in df[['DATE', col]].iterrows():    
        if pd.isnull(cols[1]):
            liste.append(np.nan)
        elif float(cols[1]) == 2400:
            cols[0] += datetime.timedelta(days=1)
            cols[1] = datetime.time(0,0)
            liste.append(combine_date_heure(cols))
        else:
            cols[1] = format_heure(cols[1])
            liste.append(combine_date_heure(cols))
    return pd.Series(liste)

# %%
df['SCHEDULED_DEPARTURE'] = create_flight_time(df, 'SCHEDULED_DEPARTURE')
df['SCHEDULED_DEPARTURE'] = pd.to_datetime(df['SCHEDULED_DEPARTURE'])
# df['DEPARTURE_TIME'] = df['DEPARTURE_TIME'].apply(format_heure)
df['DEPARTURE_TIME'] = create_flight_time(df, 'DEPARTURE_TIME')
df['DEPARTURE_TIME'] = pd.to_datetime(df['DEPARTURE_TIME'])
# df['DEPARTURE_TIME'] = df['DEPARTURE_TIME'].to_timestamp()
# df['SCHEDULED_ARRIVAL'] = df['SCHEDULED_ARRIVAL'].apply(format_heure)
df['SCHEDULED_ARRIVAL'] = create_flight_time(df, 'SCHEDULED_ARRIVAL')
df['SCHEDULED_ARRIVAL'] = pd.to_datetime(df['SCHEDULED_ARRIVAL'])
# df['SCHEDULED_ARRIVAL'] = df['SCHEDULED_ARRIVAL'].to_timestamp()
# df['ARRIVAL_TIME'] = df['ARRIVAL_TIME'].apply(format_heure)
df['ARRIVAL_TIME'] = create_flight_time(df, 'ARRIVAL_TIME')
df['ARRIVAL_TIME'] = pd.to_datetime(df['ARRIVAL_TIME'])
# df['ARRIVAL_TIME'] = df['ARRIVAL_TIME'].to_timestamp()

# %%
df.loc[:5, ['SCHEDULED_DEPARTURE', 'SCHEDULED_ARRIVAL', 'DEPARTURE_TIME',
             'ARRIVAL_TIME', 'DEPARTURE_DELAY', 'ARRIVAL_DELAY']]
# Out:
#   SCHEDULED_DEPARTURE   SCHEDULED_ARRIVAL      DEPARTURE_TIME  \
# 0 2015-04-04 11:04:00 2015-04-04 14:00:00 2015-04-04 10:59:00
# 1 2015-06-22 09:00:00 2015-06-22 10:30:00 2015-06-22 10:18:00
# 2 2015-12-27 11:35:00 2015-12-27 18:59:00 2015-12-27 11:29:00
# 3 2015-05-21 06:05:00 2015-05-21 10:00:00 2015-05-21 05:58:00
# 4 2015-07-05 22:15:00 2015-07-05 00:20:00 2015-07-05 22:13:00
# 5 2015-11-06 08:40:00 2015-11-06 12:07:00 2015-11-06 08:39:00
#
#          ARRIVAL_TIME  DEPARTURE_DELAY  ARRIVAL_DELAY
# 0 2015-04-04 13:50:00             -5.0          -10.0
# 1 2015-06-22 11:33:00             78.0           63.0
# 2 2015-12-27 18:53:00             -6.0           -6.0
# 3 2015-05-21 09:50:00             -7.0          -10.0
# 4 2015-07-05 00:24:00             -2.0            4.0
# 5 2015-11-06 12:03:00             -1.0           -4.0

# %%
remove_date=['YEAR','MONTH','DAY','DAY_OF_WEEK']
df= df.drop(remove_date, axis = 1)

# %%
df.head()
# Out:
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE  \
# 0      UA            FLL                 CLE 2015-04-04 11:04:00
# 1      WN            PHX                 LAX 2015-06-22 09:00:00
# 2      DL            SAN                 DTW 2015-12-27 11:35:00
# 3      WN            MKE                 RSW 2015-05-21 06:05:00
# 4      WN            MDW                 CLE 2015-07-05 22:15:00
#
#        DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  \
# 0 2015-04-04 10:59:00             -5.0      13.0      1112.0           176.0
# 1 2015-06-22 10:18:00             78.0      14.0      1032.0            90.0
# 2 2015-12-27 11:29:00             -6.0      29.0      1158.0           264.0
# 3 2015-05-21 05:58:00             -7.0      17.0       615.0           175.0
# 4 2015-07-05 22:13:00             -2.0      14.0      2227.0            65.0
#
#    ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN   SCHEDULED_ARRIVAL  \
# 0         171.0     149.0      1062     1341.0      9.0 2015-04-04 14:00:00
# 1          75.0      53.0       370     1125.0      8.0 2015-06-22 10:30:00
# 2         264.0     229.0      1956     1847.0      6.0 2015-12-27 18:59:00
# 3         172.0     151.0      1183      946.0      4.0 2015-05-21 10:00:00
# 4          71.0      50.0       307       17.0      7.0 2015-07-05 00:20:00
#
#          ARRIVAL_TIME  ARRIVAL_DELAY       DATE
# 0 2015-04-04 13:50:00          -10.0 2015-04-04
# 1 2015-06-22 11:33:00           63.0 2015-06-22
# 2 2015-12-27 18:53:00           -6.0 2015-12-27
# 3 2015-05-21 09:50:00          -10.0 2015-05-21
# 4 2015-07-05 00:24:00            4.0 2015-07-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285509 entries, 0 to 290953
# Data columns (total 18 columns):
# AIRLINE                285509 non-null object
# ORIGIN_AIRPORT         285509 non-null object
# DESTINATION_AIRPORT    285509 non-null object
# SCHEDULED_DEPARTURE    280181 non-null datetime64[ns]
# DEPARTURE_TIME         280181 non-null datetime64[ns]
# DEPARTURE_DELAY        285509 non-null float64
# TAXI_OUT               285509 non-null float64
# WHEELS_OFF             285509 non-null float64
# SCHEDULED_TIME         285509 non-null float64
# ELAPSED_TIME           285509 non-null float64
# AIR_TIME               285509 non-null float64
# DISTANCE               285509 non-null int64
# WHEELS_ON              285509 non-null float64
# TAXI_IN                285509 non-null float64
# SCHEDULED_ARRIVAL      280181 non-null datetime64[ns]
# ARRIVAL_TIME           280181 non-null datetime64[ns]
# ARRIVAL_DELAY          285509 non-null float64
# DATE                   285509 non-null datetime64[ns]
# dtypes: datetime64[ns](5), float64(9), int64(1), object(3)
# memory usage: 51.4+ MB

# %%
df = df[['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT','DISTANCE',
    'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY',
    'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY','TAXI_OUT',
    'WHEELS_OFF','AIR_TIME','WHEELS_ON','TAXI_IN', 'ELAPSED_TIME',
    'SCHEDULED_TIME']]

# %%
df.dropna(inplace=True)

# %%
df['ARRIVAL_TIME'][0]
# Out:
# Timestamp('2015-04-04 13:50:00')

# %%
int(str(df['SCHEDULED_ARRIVAL'][0])[-8:-6])
# Out:
# 14

# %%
# duration = datetime.datetime.combine(date.min, df['ARRIVAL_TIME'][0]) - datetime.datetime.combine(date.min,df['SCHEDULED_ARRIVAL'][0])

# %%
def time_delta(x):
    arr =x['ARRIVAL_TIME']
    sched = x['SCHEDULED_ARRIVAL']
    duration = datetime.datetime.combine(date.min, arr) - datetime.datetime.combine(date.min,sched)
    return duration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280181 entries, 0 to 285508
# Data columns (total 17 columns):
# AIRLINE                280181 non-null object
# ORIGIN_AIRPORT         280181 non-null object
# DESTINATION_AIRPORT    280181 non-null object
# DISTANCE               280181 non-null int64
# SCHEDULED_DEPARTURE    280181 non-null datetime64[ns]
# DEPARTURE_TIME         280181 non-null datetime64[ns]
# DEPARTURE_DELAY        280181 non-null float64
# SCHEDULED_ARRIVAL      280181 non-null datetime64[ns]
# ARRIVAL_TIME           280181 non-null datetime64[ns]
# ARRIVAL_DELAY          280181 non-null float64
# TAXI_OUT               280181 non-null float64
# WHEELS_OFF             280181 non-null float64
# AIR_TIME               280181 non-null float64
# WHEELS_ON              280181 non-null float64
# TAXI_IN                280181 non-null float64
# ELAPSED_TIME           280181 non-null float64
# SCHEDULED_TIME         280181 non-null float64
# dtypes: datetime64[ns](4), float64(9), int64(1), object(3)
# memory usage: 48.5+ MB

# %%
df['TOTAL_DELAY']=(df['ARRIVAL_TIME']-df['SCHEDULED_ARRIVAL']) #.astype('timedelta64[m]')
# df['TOTAL_DELAY']=df[['ARRIVAL_TIME','SCHEDULED_ARRIVAL']].apply(time_delta,axis=1)

# %%
df.head()
# Out:
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DISTANCE SCHEDULED_DEPARTURE  \
# 0      UA            FLL                 CLE      1062 2015-04-04 11:04:00
# 1      WN            PHX                 LAX       370 2015-06-22 09:00:00
# 2      DL            SAN                 DTW      1956 2015-12-27 11:35:00
# 3      WN            MKE                 RSW      1183 2015-05-21 06:05:00
# 4      WN            MDW                 CLE       307 2015-07-05 22:15:00
#
#        DEPARTURE_TIME  DEPARTURE_DELAY   SCHEDULED_ARRIVAL  \
# 0 2015-04-04 10:59:00             -5.0 2015-04-04 14:00:00
# 1 2015-06-22 10:18:00             78.0 2015-06-22 10:30:00
# 2 2015-12-27 11:29:00             -6.0 2015-12-27 18:59:00
# 3 2015-05-21 05:58:00             -7.0 2015-05-21 10:00:00
# 4 2015-07-05 22:13:00             -2.0 2015-07-05 00:20:00
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  TAXI_OUT  WHEELS_OFF  AIR_TIME  \
# 0 2015-04-04 13:50:00          -10.0      13.0      1112.0     149.0
# 1 2015-06-22 11:33:00           63.0      14.0      1032.0      53.0
# 2 2015-12-27 18:53:00           -6.0      29.0      1158.0     229.0
# 3 2015-05-21 09:50:00          -10.0      17.0       615.0     151.0
# 4 2015-07-05 00:24:00            4.0      14.0      2227.0      50.0
#
#    WHEELS_ON  TAXI_IN  ELAPSED_TIME  SCHEDULED_TIME       TOTAL_DELAY
# 0     1341.0      9.0         171.0           176.0 -1 days +23:50:00
# 1     1125.0      8.0          75.0            90.0          01:03:00
# 2     1847.0      6.0         264.0           264.0 -1 days +23:54:00
# 3      946.0      4.0         172.0           175.0 -1 days +23:50:00
# 4       17.0      7.0          71.0            65.0          00:04:00

# %%
def timedelta_format(x):
        sec = x.total_seconds()
        min_ = sec/60
        return min_

# %%
df['TOTAL_DELAY_MIN'] = df['TOTAL_DELAY'].apply(timedelta_format)

# %%
df.head()
# Out:
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DISTANCE SCHEDULED_DEPARTURE  \
# 0      UA            FLL                 CLE      1062 2015-04-04 11:04:00
# 1      WN            PHX                 LAX       370 2015-06-22 09:00:00
# 2      DL            SAN                 DTW      1956 2015-12-27 11:35:00
# 3      WN            MKE                 RSW      1183 2015-05-21 06:05:00
# 4      WN            MDW                 CLE       307 2015-07-05 22:15:00
#
#        DEPARTURE_TIME  DEPARTURE_DELAY   SCHEDULED_ARRIVAL  \
# 0 2015-04-04 10:59:00             -5.0 2015-04-04 14:00:00
# 1 2015-06-22 10:18:00             78.0 2015-06-22 10:30:00
# 2 2015-12-27 11:29:00             -6.0 2015-12-27 18:59:00
# 3 2015-05-21 05:58:00             -7.0 2015-05-21 10:00:00
# 4 2015-07-05 22:13:00             -2.0 2015-07-05 00:20:00
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  TAXI_OUT  WHEELS_OFF  AIR_TIME  \
# 0 2015-04-04 13:50:00          -10.0      13.0      1112.0     149.0
# 1 2015-06-22 11:33:00           63.0      14.0      1032.0      53.0
# 2 2015-12-27 18:53:00           -6.0      29.0      1158.0     229.0
# 3 2015-05-21 09:50:00          -10.0      17.0       615.0     151.0
# 4 2015-07-05 00:24:00            4.0      14.0      2227.0      50.0
#
#    WHEELS_ON  TAXI_IN  ELAPSED_TIME  SCHEDULED_TIME       TOTAL_DELAY  \
# 0     1341.0      9.0         171.0           176.0 -1 days +23:50:00
# 1     1125.0      8.0          75.0            90.0          01:03:00
# 2     1847.0      6.0         264.0           264.0 -1 days +23:54:00
# 3      946.0      4.0         172.0           175.0 -1 days +23:50:00
# 4       17.0      7.0          71.0            65.0          00:04:00
#
#    TOTAL_DELAY_MIN
# 0            -10.0
# 1             63.0
# 2             -6.0
# 3            -10.0
# 4              4.0

# %%
df['DELAY']=df['TOTAL_DELAY_MIN'].apply(lambda x:1 if x>0 else 0)

# %%
df.head()
# Out:
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DISTANCE SCHEDULED_DEPARTURE  \
# 0      UA            FLL                 CLE      1062 2015-04-04 11:04:00
# 1      WN            PHX                 LAX       370 2015-06-22 09:00:00
# 2      DL            SAN                 DTW      1956 2015-12-27 11:35:00
# 3      WN            MKE                 RSW      1183 2015-05-21 06:05:00
# 4      WN            MDW                 CLE       307 2015-07-05 22:15:00
#
#        DEPARTURE_TIME  DEPARTURE_DELAY   SCHEDULED_ARRIVAL  \
# 0 2015-04-04 10:59:00             -5.0 2015-04-04 14:00:00
# 1 2015-06-22 10:18:00             78.0 2015-06-22 10:30:00
# 2 2015-12-27 11:29:00             -6.0 2015-12-27 18:59:00
# 3 2015-05-21 05:58:00             -7.0 2015-05-21 10:00:00
# 4 2015-07-05 22:13:00             -2.0 2015-07-05 00:20:00
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  TAXI_OUT  WHEELS_OFF  AIR_TIME  \
# 0 2015-04-04 13:50:00          -10.0      13.0      1112.0     149.0
# 1 2015-06-22 11:33:00           63.0      14.0      1032.0      53.0
# 2 2015-12-27 18:53:00           -6.0      29.0      1158.0     229.0
# 3 2015-05-21 09:50:00          -10.0      17.0       615.0     151.0
# 4 2015-07-05 00:24:00            4.0      14.0      2227.0      50.0
#
#    WHEELS_ON  TAXI_IN  ELAPSED_TIME  SCHEDULED_TIME       TOTAL_DELAY  \
# 0     1341.0      9.0         171.0           176.0 -1 days +23:50:00
# 1     1125.0      8.0          75.0            90.0          01:03:00
# 2     1847.0      6.0         264.0           264.0 -1 days +23:54:00
# 3      946.0      4.0         172.0           175.0 -1 days +23:50:00
# 4       17.0      7.0          71.0            65.0          00:04:00
#
#    TOTAL_DELAY_MIN  DELAY
# 0            -10.0      0
# 1             63.0      1
# 2             -6.0      0
# 3            -10.0      0
# 4              4.0      1

# %%
df_info = table_data(df)
df_info
# Out:
#            dataFeatures         dataType  null  nullPct  unique  \
# 0               AIRLINE           object     0      0.0      14
# 1        ORIGIN_AIRPORT           object     0      0.0     616
# 2   DESTINATION_AIRPORT           object     0      0.0     621
# 3              DISTANCE            int64     0      0.0    1320
# 4   SCHEDULED_DEPARTURE   datetime64[ns]     0      0.0  134513
# 5        DEPARTURE_TIME   datetime64[ns]     0      0.0  197851
# 6       DEPARTURE_DELAY          float64     0      0.0     587
# 7     SCHEDULED_ARRIVAL   datetime64[ns]     0      0.0  182410
# 8          ARRIVAL_TIME   datetime64[ns]     0      0.0  201406
# 9         ARRIVAL_DELAY          float64     0      0.0     615
# 10             TAXI_OUT          float64     0      0.0     150
# 11           WHEELS_OFF          float64     0      0.0    1383
# 12             AIR_TIME          float64     0      0.0     570
# 13            WHEELS_ON          float64     0      0.0    1436
# 14              TAXI_IN          float64     0      0.0     124
# 15         ELAPSED_TIME          float64     0      0.0     588
# 16       SCHEDULED_TIME          float64     0      0.0     513
# 17          TOTAL_DELAY  timedelta64[ns]     0      0.0    1005
# 18      TOTAL_DELAY_MIN          float64     0      0.0    1005
# 19                DELAY            int64     0      0.0       2
#
#                                         sample
# 0                                     [US, B6]
# 1                                   [TWF, SAV]
# 2                                 [SAV, 12441]
# 3                                 [1547, 2688]
# 4   [2015-02-19 12:05:00, 2015-03-04 13:45:00]
# 5   [2015-05-20 16:56:00, 2015-05-19 22:03:00]
# 6                               [336.0, 193.0]
# 7   [2015-03-19 22:43:00, 2015-08-20 14:09:00]
# 8   [2015-01-20 17:17:00, 2015-06-26 10:40:00]
# 9                               [400.0, 397.0]
# 10                                [83.0, 54.0]
# 11                              [243.0, 236.0]
# 12                              [555.0, 182.0]
# 13                              [200.0, 443.0]
# 14                                [47.0, 24.0]
# 15                              [123.0, 449.0]
# 16                              [345.0, 219.0]
# 17          [0 days 05:15:00, 0 days 03:41:00]
# 18                            [273.0, -1379.0]
# 19                                      [0, 1]

# %%
df_info = table_data(df)
df_info
# Out:
#            dataFeatures         dataType  null  nullPct  unique  \
# 0               AIRLINE           object     0      0.0      14
# 1        ORIGIN_AIRPORT           object     0      0.0     616
# 2   DESTINATION_AIRPORT           object     0      0.0     621
# 3              DISTANCE            int64     0      0.0    1320
# 4   SCHEDULED_DEPARTURE   datetime64[ns]     0      0.0  134513
# 5        DEPARTURE_TIME   datetime64[ns]     0      0.0  197851
# 6       DEPARTURE_DELAY          float64     0      0.0     587
# 7     SCHEDULED_ARRIVAL   datetime64[ns]     0      0.0  182410
# 8          ARRIVAL_TIME   datetime64[ns]     0      0.0  201406
# 9         ARRIVAL_DELAY          float64     0      0.0     615
# 10             TAXI_OUT          float64     0      0.0     150
# 11           WHEELS_OFF          float64     0      0.0    1383
# 12             AIR_TIME          float64     0      0.0     570
# 13            WHEELS_ON          float64     0      0.0    1436
# 14              TAXI_IN          float64     0      0.0     124
# 15         ELAPSED_TIME          float64     0      0.0     588
# 16       SCHEDULED_TIME          float64     0      0.0     513
# 17          TOTAL_DELAY  timedelta64[ns]     0      0.0    1005
# 18      TOTAL_DELAY_MIN          float64     0      0.0    1005
# 19                DELAY            int64     0      0.0       2
#
#                                         sample
# 0                                     [WN, NK]
# 1                                 [SBN, 14520]
# 2                                   [GSP, COU]
# 3                                 [2355, 1553]
# 4   [2015-08-07 12:18:00, 2015-02-24 04:15:00]
# 5   [2015-06-29 10:06:00, 2015-07-07 16:47:00]
# 6                               [205.0, 505.0]
# 7   [2015-06-15 18:41:00, 2015-05-15 16:35:00]
# 8   [2015-04-20 10:57:00, 2015-03-05 09:59:00]
# 9                                [-16.0, -5.0]
# 10                                 [2.0, 36.0]
# 11                               [621.0, 23.0]
# 12                              [373.0, 421.0]
# 13                             [1057.0, 649.0]
# 14                                [55.0, 67.0]
# 15                              [664.0, 242.0]
# 16                              [151.0, 389.0]
# 17        [0 days 23:34:00, -1 days +09:52:00]
# 18                              [441.0, 119.0]
# 19                                      [0, 1]

# %%
df['DELAY'].value_counts()
# Out:
# 0    180515
# 1     99666
# Name: DELAY, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280181 entries, 0 to 285508
# Data columns (total 20 columns):
# AIRLINE                280181 non-null object
# ORIGIN_AIRPORT         280181 non-null object
# DESTINATION_AIRPORT    280181 non-null object
# DISTANCE               280181 non-null int64
# SCHEDULED_DEPARTURE    280181 non-null datetime64[ns]
# DEPARTURE_TIME         280181 non-null datetime64[ns]
# DEPARTURE_DELAY        280181 non-null float64
# SCHEDULED_ARRIVAL      280181 non-null datetime64[ns]
# ARRIVAL_TIME           280181 non-null datetime64[ns]
# ARRIVAL_DELAY          280181 non-null float64
# TAXI_OUT               280181 non-null float64
# WHEELS_OFF             280181 non-null float64
# AIR_TIME               280181 non-null float64
# WHEELS_ON              280181 non-null float64
# TAXI_IN                280181 non-null float64
# ELAPSED_TIME           280181 non-null float64
# SCHEDULED_TIME         280181 non-null float64
# TOTAL_DELAY            280181 non-null timedelta64[ns]
# TOTAL_DELAY_MIN        280181 non-null float64
# DELAY                  280181 non-null int64
# dtypes: datetime64[ns](4), float64(10), int64(2), object(3), timedelta64[ns](1)
# memory usage: 54.9+ MB

# %%
airlines = pd.read_csv('./flight-delays/airlines.csv')
airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
abbr_airlines = airlines.set_index('IATA_CODE')['AIRLINE'].to_dict()
abbr_airlines
# Out:
# {'UA': 'United Air Lines Inc.',
#  'AA': 'American Airlines Inc.',
#  'US': 'US Airways Inc.',
#  'F9': 'Frontier Airlines Inc.',
#  'B6': 'JetBlue Airways',
#  'OO': 'Skywest Airlines Inc.',
#  'AS': 'Alaska Airlines Inc.',
#  'NK': 'Spirit Air Lines',
#  'WN': 'Southwest Airlines Co.',
#  'DL': 'Delta Air Lines Inc.',
#  'EV': 'Atlantic Southeast Airlines',
#  'HA': 'Hawaiian Airlines Inc.',
#  'MQ': 'American Eagle Airlines Inc.',
#  'VX': 'Virgin America'}

# %%
df['ABBR_AIRLINE']=df['AIRLINE'].apply(lambda x :abbr_airlines[x])

# %%
df = df[['AIRLINE','ABBR_AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
    'DISTANCE', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY',
    'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY','TAXI_OUT',
    'WHEELS_OFF','AIR_TIME','WHEELS_ON','TAXI_IN', 'ELAPSED_TIME',
    'SCHEDULED_TIME','TOTAL_DELAY','TOTAL_DELAY_MIN','DELAY']]

# %% [markdown]
# df.to_csv('flights_sample_cleaned.csv',index=False)

# %% [markdown]
# df = pd.read_csv('flights_sample_cleaned.csv')

# %%
df.head()
# Out:
#   AIRLINE            ABBR_AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0      UA   United Air Lines Inc.            FLL                 CLE
# 1      WN  Southwest Airlines Co.            PHX                 LAX
# 2      DL    Delta Air Lines Inc.            SAN                 DTW
# 3      WN  Southwest Airlines Co.            MKE                 RSW
# 4      WN  Southwest Airlines Co.            MDW                 CLE
#
#    DISTANCE SCHEDULED_DEPARTURE      DEPARTURE_TIME  DEPARTURE_DELAY  \
# 0      1062 2015-04-04 11:04:00 2015-04-04 10:59:00             -5.0
# 1       370 2015-06-22 09:00:00 2015-06-22 10:18:00             78.0
# 2      1956 2015-12-27 11:35:00 2015-12-27 11:29:00             -6.0
# 3      1183 2015-05-21 06:05:00 2015-05-21 05:58:00             -7.0
# 4       307 2015-07-05 22:15:00 2015-07-05 22:13:00             -2.0
#
#     SCHEDULED_ARRIVAL        ARRIVAL_TIME  ARRIVAL_DELAY  TAXI_OUT  \
# 0 2015-04-04 14:00:00 2015-04-04 13:50:00          -10.0      13.0
# 1 2015-06-22 10:30:00 2015-06-22 11:33:00           63.0      14.0
# 2 2015-12-27 18:59:00 2015-12-27 18:53:00           -6.0      29.0
# 3 2015-05-21 10:00:00 2015-05-21 09:50:00          -10.0      17.0
# 4 2015-07-05 00:20:00 2015-07-05 00:24:00            4.0      14.0
#
#    WHEELS_OFF  AIR_TIME  WHEELS_ON  TAXI_IN  ELAPSED_TIME  SCHEDULED_TIME  \
# 0      1112.0     149.0     1341.0      9.0         171.0           176.0
# 1      1032.0      53.0     1125.0      8.0          75.0            90.0
# 2      1158.0     229.0     1847.0      6.0         264.0           264.0
# 3       615.0     151.0      946.0      4.0         172.0           175.0
# 4      2227.0      50.0       17.0      7.0          71.0            65.0
#
#         TOTAL_DELAY  TOTAL_DELAY_MIN  DELAY
# 0 -1 days +23:50:00            -10.0      0
# 1          01:03:00             63.0      1
# 2 -1 days +23:54:00             -6.0      0
# 3 -1 days +23:50:00            -10.0      0
# 4          00:04:00              4.0      1

# %%
df[df['TOTAL_DELAY_MIN'] <-100].sort_values(by='TOTAL_DELAY_MIN',ascending=False)
# Out:
#        AIRLINE                  ABBR_AIRLINE ORIGIN_AIRPORT  \
# 118614      AA        American Airlines Inc.            DEN
# 11585       UA         United Air Lines Inc.            MCO
# 81869       DL          Delta Air Lines Inc.            JAX
# 264633      OO         Skywest Airlines Inc.            DTW
# 74849       MQ  American Eagle Airlines Inc.            MOB
# 91606       UA         United Air Lines Inc.          11618
# 81008       WN        Southwest Airlines Co.            PIT
# 169931      UA         United Air Lines Inc.            IAD
# 39641       AA        American Airlines Inc.          14831
# 84739       WN        Southwest Airlines Co.            SAN
# 282655      MQ  American Eagle Airlines Inc.            DFW
# 258360      DL          Delta Air Lines Inc.            ATL
# 265884      DL          Delta Air Lines Inc.            ATL
# 60800       EV   Atlantic Southeast Airlines            MSP
# 253887      HA        Hawaiian Airlines Inc.          14057
# 145238      OO         Skywest Airlines Inc.            SLC
# 252122      WN        Southwest Airlines Co.            LIT
# 104743      AA        American Airlines Inc.            PHX
# 64530       MQ  American Eagle Airlines Inc.            ORD
# 186433      EV   Atlantic Southeast Airlines            CLE
# 74942       WN        Southwest Airlines Co.          15016
# 103161      AS          Alaska Airlines Inc.            SEA
# 6325        OO         Skywest Airlines Inc.          14869
# 107214      DL          Delta Air Lines Inc.            MSP
# 13257       DL          Delta Air Lines Inc.            MSP
# 209164      AS          Alaska Airlines Inc.            SEA
# 144198      UA         United Air Lines Inc.            PDX
# 208973      UA         United Air Lines Inc.            DEN
# 4087        NK              Spirit Air Lines            PBG
#        AIRLINE                  ABBR_AIRLINE ORIGIN_AIRPORT  \
# 97          DL          Delta Air Lines Inc.          11433
# 382         DL          Delta Air Lines Inc.          11433
# 859         DL          Delta Air Lines Inc.            PHX
# 1117        EV   Atlantic Southeast Airlines            EWR
# 1144        AA        American Airlines Inc.            PHL
# 1165        OO         Skywest Airlines Inc.            CMH
# 1498        OO         Skywest Airlines Inc.            DEN
# 1959        AA        American Airlines Inc.            DFW
# 2015        WN        Southwest Airlines Co.            ATL
# 2049        MQ  American Eagle Airlines Inc.            DFW
# 2282        DL          Delta Air Lines Inc.            DTW
# 3034        WN        Southwest Airlines Co.            PHX
# 3641        US               US Airways Inc.            CLT
# 4215        WN        Southwest Airlines Co.            DEN
# 4572        WN        Southwest Airlines Co.            MCO
# 4948        AA        American Airlines Inc.            BOS
# 5181        DL          Delta Air Lines Inc.            MSP
# 6008        OO         Skywest Airlines Inc.            ABQ
# 7644        WN        Southwest Airlines Co.            PIT
# 8553        OO         Skywest Airlines Inc.            SFO
# 8773        EV   Atlantic Southeast Airlines          10721
# 9501        AA        American Airlines Inc.            DFW
# 9943        DL          Delta Air Lines Inc.            DTW
# 10662       WN        Southwest Airlines Co.            AUS
# 10853       DL          Delta Air Lines Inc.            DTW
# 11737       DL          Delta Air Lines Inc.            MCO
# 13340       MQ  American Eagle Airlines Inc.            DFW
# 13523       AA        American Airlines Inc.            LGA
# 13534       B6               JetBlue Airways          11697
# 13548       OO         Skywest Airlines Inc.            MSP
# ...        ...                           ...            ...
# 273323      EV   Atlantic Southeast Airlines            TUL
# 273364      DL          Delta Air Lines Inc.            ATL
# 273495      AA        American Airlines Inc.            LGA
# 274022      WN        Southwest Airlines Co.          13796
# 274197      WN        Southwest Airlines Co.            MCO
# 274267      WN        Southwest Airlines Co.            HOU
# 274715      NK              Spirit Air Lines            LAX
# 275375      WN        Southwest Airlines Co.            LAS
# 275378      AA        American Airlines Inc.            DFW
# 275662      B6               JetBlue Airways            SEA
# 276053      EV   Atlantic Southeast Airlines            ABE
# 276686      AA        American Airlines Inc.            ORD
# 277124      EV   Atlantic Southeast Airlines            MSP
# 277170      WN        Southwest Airlines Co.            SAT
# 277509      DL          Delta Air Lines Inc.            PBI
# 277556      WN        Southwest Airlines Co.            OAK
# 277932      MQ  American Eagle Airlines Inc.            ORD
# 278481      NK              Spirit Air Lines            OAK
# 278521      DL          Delta Air Lines Inc.          10397
# 279231      AA        American Airlines Inc.            MIA
# 281194      AA        American Airlines Inc.            MIA
# 282553      AA        American Airlines Inc.            SFO
# 283235      OO         Skywest Airlines Inc.            SFO
# 283360      EV   Atlantic Southeast Airlines            IAH
# 283385      DL          Delta Air Lines Inc.            LAX
# 283977      DL          Delta Air Lines Inc.            ATL
# 284413      DL          Delta Air Lines Inc.            LGA
# 284636      WN        Southwest Airlines Co.            BNA
# 284866      WN        Southwest Airlines Co.            ONT
# 285463      US               US Airways Inc.            PHX
#
#        DESTINATION_AIRPORT  DISTANCE SCHEDULED_DEPARTURE      DEPARTURE_TIME  \
# 97                   11278       405 2015-08-28 23:07:00 2015-08-28 23:05:00
# 278481          86.0            84.0    23:45:00           1425.0      1
# 278521         111.0           118.0    23:46:00           1426.0      1
# 279231         156.0           148.0    23:38:00           1418.0      1
# 281194         144.0           156.0    23:46:00           1426.0      1
# 282553         206.0           215.0    23:39:00           1419.0      1
# 283235          61.0            65.0    23:43:00           1423.0      1
# 283360          73.0            74.0    23:37:00           1417.0      1
# 283385         155.0           155.0    23:51:00           1431.0      1
# 283977          50.0            59.0    23:42:00           1422.0      1
# 284413         166.0           166.0    23:52:00           1432.0      1
# 284636         101.0           110.0    23:48:00           1428.0      1
# 284866          85.0            75.0    23:30:00           1410.0      1
# 285463         330.0           297.0    23:42:00           1422.0      1
#
# [615 rows x 21 columns]

# %%
df
# Out:
#        AIRLINE                  ABBR_AIRLINE ORIGIN_AIRPORT  \
# 0           UA         United Air Lines Inc.            FLL
# 1           WN        Southwest Airlines Co.            PHX
# 2           DL          Delta Air Lines Inc.            SAN
# 3           WN        Southwest Airlines Co.            MKE
# 4           WN        Southwest Airlines Co.            MDW
# 5           AA        American Airlines Inc.            PDX
# 6           WN        Southwest Airlines Co.            STL
# 7           DL          Delta Air Lines Inc.            ATL
# 8           DL          Delta Air Lines Inc.            SFO
# 9           WN        Southwest Airlines Co.            MDW
# 10          WN        Southwest Airlines Co.            LAS
# 11          WN        Southwest Airlines Co.            MDW
# 12          MQ  American Eagle Airlines Inc.            ORD
# 13          WN        Southwest Airlines Co.            GSP
# 14          WN        Southwest Airlines Co.            HOU
# 15          WN        Southwest Airlines Co.            BWI
# 16          UA         United Air Lines Inc.            ORD
# 17          AA        American Airlines Inc.          10693
# 18          OO         Skywest Airlines Inc.            SFO
# 19          MQ  American Eagle Airlines Inc.            GRK
# 20          AA        American Airlines Inc.            MIA
# 21          AA        American Airlines Inc.            SDF
# 22          OO         Skywest Airlines Inc.            ORD
# 23          DL          Delta Air Lines Inc.            MSP
# 24          MQ  American Eagle Airlines Inc.            CMH
# 25          UA         United Air Lines Inc.            DCA
# 26          WN        Southwest Airlines Co.            SEA
# 27          OO         Skywest Airlines Inc.            SAT
# 28          UA         United Air Lines Inc.            DEN
# 29          UA         United Air Lines Inc.            IAH
# ...        ...                           ...            ...
# 285479      MQ  American Eagle Airlines Inc.          13930
# 285480      OO         Skywest Airlines Inc.            RDM
# 285481      AA        American Airlines Inc.            MIA
# 285482      AA        American Airlines Inc.            DFW
# 285483      AA        American Airlines Inc.            LGA
# 285484      UA         United Air Lines Inc.            DCA
# 285485      WN        Southwest Airlines Co.            DCA
# 285486      F9        Frontier Airlines Inc.            RDU
# 285487      WN        Southwest Airlines Co.            BUR
# 285488      EV   Atlantic Southeast Airlines            ALB
# 285489      WN        Southwest Airlines Co.            BWI
# 285490      AA        American Airlines Inc.          11540
# 285491      MQ  American Eagle Airlines Inc.            ORD
# 285492      OO         Skywest Airlines Inc.            BUR
# 285493      DL          Delta Air Lines Inc.            SLC
# 285494      WN        Southwest Airlines Co.            SFO
# 285495      EV   Atlantic Southeast Airlines          13931
# 285496      US               US Airways Inc.            CLT
# 285482         167.0           183.0          03:25:00            205.0      1
# 285483         188.0           188.0 -1 days +23:34:00            -26.0      0
# 285484         123.0           123.0          00:05:00              5.0      1
# 285485         119.0           125.0          00:22:00             22.0      1
# 285486         236.0           220.0          00:02:00              2.0      1
# 285487         115.0           135.0 -1 days +23:49:00            -11.0      0
# 285488          93.0           116.0          00:03:00              3.0      1
# 285489         184.0           195.0 -1 days +23:45:00            -15.0      0
# 285490         100.0           113.0 -1 days +23:44:00            -16.0      0
# 285491         102.0           109.0          00:35:00             35.0      1
# 285492          75.0            81.0 -1 days +23:51:00             -9.0      0
# 285493         105.0           103.0 -1 days +23:39:00            -21.0      0
# 285494         100.0           115.0 -1 days +23:54:00             -6.0      0
# 285495         107.0            85.0 -1 days +23:49:00            -11.0      0
# 285496         112.0           116.0          00:54:00             54.0      1
# 285497         182.0           160.0          01:05:00             65.0      1
# 285498          90.0            95.0          00:24:00             24.0      1
# 285499          49.0            59.0 -1 days +23:48:00            -12.0      0
# 285500         112.0           111.0 -1 days +23:40:00            -20.0      0
# 285501         331.0           372.0          01:06:00             66.0      1
# 285502         285.0           309.0          00:00:00              0.0      0
# 285503          80.0            82.0          00:05:00              5.0      1
# 285504          78.0            65.0          00:17:00             17.0      1
# 285505         130.0           139.0 -1 days +23:56:00             -4.0      0
# 285506         173.0           192.0 -1 days +23:51:00             -9.0      0
# 285507          96.0            94.0 -1 days +23:46:00            -14.0      0
# 285508         316.0           337.0 -1 days +23:48:00            -12.0      0
#
# [280181 rows x 21 columns]

# %%
con_=(df['TOTAL_DELAY_MIN'] <-100)|(df['TOTAL_DELAY_MIN'] >1000)
df = df.drop(df[con_].index)

# %%
df[df['TOTAL_DELAY_MIN'] >1000]
# Out:
# Empty DataFrame
# Columns: [AIRLINE, ABBR_AIRLINE, ORIGIN_AIRPORT, DESTINATION_AIRPORT, DISTANCE, SCHEDULED_DEPARTURE, DEPARTURE_TIME, DEPARTURE_DELAY, SCHEDULED_ARRIVAL, ARRIVAL_TIME, ARRIVAL_DELAY, TAXI_OUT, WHEELS_OFF, AIR_TIME, WHEELS_ON, TAXI_IN, ELAPSED_TIME, SCHEDULED_TIME, TOTAL_DELAY, TOTAL_DELAY_MIN, DELAY]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276268 entries, 0 to 285508
# Data columns (total 21 columns):
# AIRLINE                276268 non-null object
# ABBR_AIRLINE           276268 non-null object
# ORIGIN_AIRPORT         276268 non-null object
# DESTINATION_AIRPORT    276268 non-null object
# DISTANCE               276268 non-null int64
# SCHEDULED_DEPARTURE    276268 non-null datetime64[ns]
# DEPARTURE_TIME         276268 non-null datetime64[ns]
# DEPARTURE_DELAY        276268 non-null float64
# SCHEDULED_ARRIVAL      276268 non-null datetime64[ns]
# ARRIVAL_TIME           276268 non-null datetime64[ns]
# ARRIVAL_DELAY          276268 non-null float64
# TAXI_OUT               276268 non-null float64
# WHEELS_OFF             276268 non-null float64
# AIR_TIME               276268 non-null float64
# WHEELS_ON              276268 non-null float64
# TAXI_IN                276268 non-null float64
# ELAPSED_TIME           276268 non-null float64
# SCHEDULED_TIME         276268 non-null float64
# TOTAL_DELAY            276268 non-null timedelta64[ns]
# TOTAL_DELAY_MIN        276268 non-null float64
# DELAY                  276268 non-null int64
# dtypes: datetime64[ns](4), float64(10), int64(2), object(4), timedelta64[ns](1)
# memory usage: 46.4+ MB

# %% [markdown]
# # EDA

# %% [markdown]
# to make things clearer abbreviations of the airlines will be retrievied from airline.csv file and saved into dictionary for further usage

# %% [markdown]
# Showing the min, max, mean of each airlines on the TOTAL_DELAY column

# %%
gb_airlines = df.groupby('AIRLINE')
des_total_delay = gb_airlines['TOTAL_DELAY_MIN'].describe().sort_values(by=['mean','75%'],ascending=False)
des_total_delay.index = [abbr_airlines[item] for item in abbr_airlines]
des_total_delay
# Out:
#                                 count      mean        std   min   25%  50%  \
# United Air Lines Inc.         24645.0  3.425806  34.234472 -57.0 -13.0 -5.0
# American Airlines Inc.         8325.0  3.367327  33.592165 -52.0 -13.0 -5.0
# US Airways Inc.               26785.0  3.232257  33.728615 -59.0 -13.0 -5.0
# Frontier Airlines Inc.         5413.0  3.178829  32.669510 -52.0 -13.0 -5.0
# JetBlue Airways               12601.0  3.083485  33.717249 -61.0 -13.0 -5.0
# Skywest Airlines Inc.         27790.0  3.053472  33.808830 -65.0 -13.0 -5.0
# Alaska Airlines Inc.          13406.0  3.006117  33.765238 -71.0 -13.0 -5.0
# Spirit Air Lines              60026.0  3.002715  34.059040 -70.0 -13.0 -5.0
# Southwest Airlines Co.         3006.0  2.988689  35.369641 -47.0 -13.0 -5.0
# Delta Air Lines Inc.          34536.0  2.860522  34.520484 -58.0 -13.0 -5.0
# Atlantic Southeast Airlines   42151.0  2.783635  34.085906 -69.0 -13.0 -5.0
# Hawaiian Airlines Inc.         4380.0  2.739269  32.384600 -66.0 -13.0 -5.0
# American Eagle Airlines Inc.   9569.0  2.727140  34.300293 -80.0 -13.0 -5.0
# Virgin America                 3635.0  2.376891  32.556355 -56.0 -13.0 -5.0
#
#                               75%    max
# United Air Lines Inc.         7.0  610.0
# American Airlines Inc.        7.0  502.0
# US Airways Inc.               7.0  651.0
# Frontier Airlines Inc.        7.0  376.0
# JetBlue Airways               7.0  508.0
# Skywest Airlines Inc.         7.0  711.0
# Alaska Airlines Inc.          7.0  530.0
# Spirit Air Lines              7.0  774.0
# Southwest Airlines Co.        7.0  591.0
# Delta Air Lines Inc.          7.0  951.0
# Atlantic Southeast Airlines   7.0  851.0
# Hawaiian Airlines Inc.        7.0  421.0
# American Eagle Airlines Inc.  7.0  679.0
# Virgin America                6.0  535.0

# %% [markdown]
# From this dataframe, it can be concluded that the United Airlines has the highest mean of the TOTAL_DELAY. Also We can see that there are many outliers for all of the data, where we can say that the cause of the delay is probably due to an unexpected circumtances

# %% [markdown]
# Dropping the data which has more than 60 mins of delay on total to look at the non outlier data

# %%
condition = (df['TOTAL_DELAY_MIN']<=60)&(df['DEPARTURE_DELAY']<=120)&(df['ARRIVAL_DELAY']<=120)
gb_airlines = df[condition].groupby('AIRLINE')

# %% [markdown]
# ### Departure Delay per Airline

# %%
des_dep_delay = gb_airlines['DEPARTURE_DELAY'].describe().sort_values(by=['mean','75%'],ascending=False)
des_dep_delay.index = [abbr_airlines[item] for item in abbr_airlines]
des_dep_delay
# Out:
#                                 count      mean        std   min  25%  50%  \
# United Air Lines Inc.          4937.0  8.908244  24.922113 -23.0 -6.0 -1.0
# American Airlines Inc.        22567.0  8.315195  21.521507 -36.0 -4.0  0.0
# US Airways Inc.               56143.0  7.627077  19.712531 -14.0 -3.0  0.0
# Frontier Airlines Inc.        11605.0  6.439638  22.011300 -23.0 -6.0 -2.0
# JetBlue Airways                4027.0  5.712193  23.179527 -23.0 -7.0 -3.0
# Skywest Airlines Inc.         12382.0  5.218139  21.252209 -26.0 -6.0 -3.0
# Alaska Airlines Inc.           2820.0  5.078723  19.083437 -20.0 -4.0 -1.0
# Spirit Air Lines              32159.0  4.553593  19.602135 -29.0 -5.0 -2.0
# Southwest Airlines Co.        24706.0  3.880272  21.197192 -38.0 -6.0 -3.0
# Delta Air Lines Inc.           8949.0  3.777629  18.771791 -22.0 -5.0 -3.0
# Atlantic Southeast Airlines   39502.0  3.756797  16.774617 -20.0 -4.0 -2.0
# Hawaiian Airlines Inc.        25796.0  3.464064  20.513457 -34.0 -7.0 -3.0
# American Eagle Airlines Inc.   7846.0 -0.068443  16.807280 -82.0 -8.0 -4.0
# Virgin America                 3462.0 -0.352397  12.699765 -22.0 -7.0 -4.0
#
#                                75%    max
# United Air Lines Inc.         13.0  119.0
# American Airlines Inc.        11.0  120.0
# US Airways Inc.               10.0  120.0
# Frontier Airlines Inc.         9.0  120.0
# JetBlue Airways                8.0  119.0
# Skywest Airlines Inc.          6.0  119.0
# Alaska Airlines Inc.           5.0  118.0
# Spirit Air Lines               4.0  120.0
# Southwest Airlines Co.         3.0  120.0
# Delta Air Lines Inc.           3.0  120.0
# Atlantic Southeast Airlines    3.0  120.0
# Hawaiian Airlines Inc.         2.0  120.0
# American Eagle Airlines Inc.   0.0  120.0
# Virgin America                 1.0  112.0

# %% [markdown]
# ### Arrival Delay per Airline

# %%
des_arr_delay = gb_airlines['ARRIVAL_DELAY'].describe().sort_values(by=['mean','75%'],ascending=False)
des_arr_delay.index = [abbr_airlines[item] for item in abbr_airlines]
des_arr_delay
# Out:
#                                 count      mean        std   min   25%  50%  \
# United Air Lines Inc.          4937.0  7.314158  27.676777 -52.0 -10.0 -1.0
# American Airlines Inc.         4027.0  4.339707  26.547510 -50.0 -12.0 -3.0
# US Airways Inc.               24706.0  1.676799  24.083447 -55.0 -13.0 -5.0
# Frontier Airlines Inc.        25796.0  1.481625  22.944609 -51.0 -12.0 -4.0
# JetBlue Airways               56143.0  1.360526  22.447754 -61.0 -12.0 -4.0
# Skywest Airlines Inc.          8949.0  1.315566  22.794682 -71.0 -12.0 -4.0
# Alaska Airlines Inc.           3462.0  1.254766  14.909932 -49.0  -7.0 -2.0
# Spirit Air Lines              12382.0  1.236957  25.750693 -55.0 -15.0 -6.0
# Southwest Airlines Co.        11605.0  1.127014  25.834392 -64.0 -15.0 -5.0
# Delta Air Lines Inc.           2820.0  0.986879  23.864199 -58.0 -12.0 -3.0
# Atlantic Southeast Airlines   22567.0 -0.631276  25.014305 -62.0 -16.0 -7.0
# Hawaiian Airlines Inc.        32159.0 -0.890979  23.551626 -67.0 -15.0 -6.0
# American Eagle Airlines Inc.   7846.0 -2.921489  20.369955 -80.0 -14.0 -6.0
# Virgin America                39502.0 -3.416409  20.709964 -70.0 -15.0 -8.0
#
#                                75%    max
# United Air Lines Inc.         16.0  120.0
# American Airlines Inc.        12.0  120.0
# US Airways Inc.                7.0  120.0
# Frontier Airlines Inc.         7.0  120.0
# JetBlue Airways                7.0  120.0
# Skywest Airlines Inc.          8.0  120.0
# Alaska Airlines Inc.           5.0  120.0
# Spirit Air Lines               8.0  120.0
# Southwest Airlines Co.         9.0  120.0
# Delta Air Lines Inc.           8.0  120.0
# Atlantic Southeast Airlines    7.0  120.0
# Hawaiian Airlines Inc.         6.0  120.0
# American Eagle Airlines Inc.   4.0  118.0
# Virgin America                 2.0  120.0

# %% [markdown]
# ### Total Delay per Airline

# %%
des_total_delay = gb_airlines['TOTAL_DELAY_MIN'].describe().sort_values(by=['mean','75%'],ascending=False)
des_total_delay.index = [abbr_airlines[item] for item in abbr_airlines]
des_total_delay
# Out:
#                                 count      mean        std   min   25%  50%  \
# United Air Lines Inc.          7846.0 -2.609228  17.133569 -52.0 -13.0 -6.0
# American Airlines Inc.         4937.0 -2.745797  17.056929 -52.0 -13.0 -6.0
# US Airways Inc.               22567.0 -2.755705  17.229586 -57.0 -14.0 -6.0
# Frontier Airlines Inc.         4027.0 -2.755898  17.104868 -66.0 -13.0 -6.0
# JetBlue Airways                2820.0 -2.767730  17.337160 -47.0 -14.0 -6.0
# Skywest Airlines Inc.         11605.0 -2.820853  16.981260 -61.0 -14.0 -6.0
# Alaska Airlines Inc.          24706.0 -2.841536  17.255224 -59.0 -14.0 -6.0
# Spirit Air Lines              56143.0 -2.855957  17.076971 -70.0 -14.0 -6.0
# Southwest Airlines Co.        25796.0 -2.870445  17.154244 -65.0 -14.0 -6.0
# Delta Air Lines Inc.          12382.0 -2.884833  17.058842 -71.0 -14.0 -6.0
# Atlantic Southeast Airlines    3462.0 -2.893414  17.218782 -56.0 -14.0 -6.0
# Hawaiian Airlines Inc.        39502.0 -2.929953  17.075369 -69.0 -14.0 -6.0
# American Eagle Airlines Inc.  32159.0 -2.961784  17.102567 -58.0 -14.0 -6.0
# Virgin America                 8949.0 -3.046597  17.070345 -80.0 -14.0 -6.0
#
#                               75%   max
# United Air Lines Inc.         4.0  60.0
# American Airlines Inc.        5.0  60.0
# US Airways Inc.               4.0  60.0
# Frontier Airlines Inc.        4.0  60.0
# JetBlue Airways               5.0  60.0
# Skywest Airlines Inc.         4.0  60.0
# Alaska Airlines Inc.          5.0  60.0
# Spirit Air Lines              4.0  60.0
# Southwest Airlines Co.        5.0  60.0
# Delta Air Lines Inc.          5.0  60.0
# Atlantic Southeast Airlines   4.0  60.0
# Hawaiian Airlines Inc.        4.0  60.0
# American Eagle Airlines Inc.  4.0  60.0
# Virgin America                4.0  60.0

# %% [markdown]
# ## Visualisation

# %% [markdown]
# ### Delay VS Airline Companies

# %%
colors = ['royalblue', 'grey', 'wheat', 'c', 'firebrick', 'seagreen', 'lightskyblue',
          'lightcoral', 'yellowgreen', 'gold', 'tomato', 'violet', 'aquamarine', 'chartreuse']

# %% [markdown]
# _Airline with most flight recorded_

# %%
plt.figure(figsize=(16,15))
ax3 = sns.countplot(y='ABBR_AIRLINE', palette = colors,
                    data=df,order = df['ABBR_AIRLINE'].value_counts().index)

# %%
df['ABBR_AIRLINE'].value_counts()
# Out:
# Southwest Airlines Co.          60026
# Delta Air Lines Inc.            42151
# American Airlines Inc.          34536
# Skywest Airlines Inc.           27790
# Atlantic Southeast Airlines     26785
# United Air Lines Inc.           24645
# American Eagle Airlines Inc.    13406
# JetBlue Airways                 12601
# US Airways Inc.                  9569
# Alaska Airlines Inc.             8325
# Spirit Air Lines                 5413
# Frontier Airlines Inc.           4380
# Hawaiian Airlines Inc.           3635
# Virgin America                   3006
# Name: ABBR_AIRLINE, dtype: int64

# %% [markdown]
# _Airline with most __DELAYED__ flight recorded_

# %%
plt.figure(figsize=(16,15))
ax3 = sns.countplot(y='ABBR_AIRLINE', palette = colors,
                    data=df[df['DELAY']==1],
                    order = df[df['DELAY']==1]['ABBR_AIRLINE'].value_counts().index)

# %%
df[df['DELAY']==1]['ABBR_AIRLINE'].value_counts()
# Out:
# Southwest Airlines Co.          21540
# Delta Air Lines Inc.            15006
# American Airlines Inc.          12277
# Skywest Airlines Inc.           10125
# Atlantic Southeast Airlines      9596
# United Air Lines Inc.            8953
# American Eagle Airlines Inc.     4778
# JetBlue Airways                  4498
# US Airways Inc.                  3357
# Alaska Airlines Inc.             3058
# Spirit Air Lines                 1958
# Frontier Airlines Inc.           1576
# Hawaiian Airlines Inc.           1270
# Virgin America                   1059
# Name: ABBR_AIRLINE, dtype: int64

# %% [markdown]
# Since the data for each of the Airlines variate, Ratio of delayed and total data is shown below

# %%
airlines_count = df['ABBR_AIRLINE'].value_counts().sort_index()
delay_1 = df[df['DELAY']==1]['ABBR_AIRLINE'].value_counts().sort_index()

delay_pct = delay_1/airlines_count
delay_pct = delay_pct.sort_values(ascending=False)
delay_pct
# Out:
# Alaska Airlines Inc.            0.367327
# Skywest Airlines Inc.           0.364340
# United Air Lines Inc.           0.363279
# Spirit Air Lines                0.361722
# Frontier Airlines Inc.          0.359817
# Southwest Airlines Co.          0.358845
# Atlantic Southeast Airlines     0.358260
# JetBlue Airways                 0.356956
# American Eagle Airlines Inc.    0.356408
# Delta Air Lines Inc.            0.356006
# American Airlines Inc.          0.355484
# Virgin America                  0.352295
# US Airways Inc.                 0.350820
# Hawaiian Airlines Inc.          0.349381
# Name: ABBR_AIRLINE, dtype: float64

# %%
ax = sns.barplot(x=delay_pct.values,y=delay_pct.index)

# %% [markdown]
# _From this we can somewhat conclude that all airlines delay possibilty are more or less the same so there is not so much of a significant correlation here._

# %% [markdown]
# Although airline company are not that relavant to delayed flight, it turns out that the duration of the delay has some correlation to the airlines companies as shown below

# %%
plt.figure(figsize=(16,15))
labels = [s for s in  des_total_delay.index]
ax3 = sns.stripplot(y='ABBR_AIRLINE', x='TOTAL_DELAY_MIN', size = 4, palette = colors,
                    data=df, linewidth = 0.5,  jitter=True)
ax3.yaxis.label.set_visible(False)

# %% [markdown]
# _From that graph we can conclude that Virgin America has the least duration of delay(on avg) in this data and Southwest Airlines has longer delays_

# %% [markdown]
# __Now comparing the correlation between departure time(SD_MONTH) to the total delay in min (TOTAL_DELAY_MIN)__

# %%
df['SD_MONTH']=df['SCHEDULED_DEPARTURE'].dt.month

# %%
df = df[['AIRLINE', 'ABBR_AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
         'DISTANCE','SD_MONTH','SCHEDULED_DEPARTURE', 'DEPARTURE_TIME',
         'DEPARTURE_DELAY','SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
         'ARRIVAL_DELAY', 'TAXI_OUT','WHEELS_OFF', 'AIR_TIME', 
         'WHEELS_ON', 'TAXI_IN', 'ELAPSED_TIME','SCHEDULED_TIME', 
         'TOTAL_DELAY', 'TOTAL_DELAY_MIN', 'DELAY']]

# %%
df.head()
# Out:
#   AIRLINE            ABBR_AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0      UA   United Air Lines Inc.            FLL                 CLE
# 1      WN  Southwest Airlines Co.            PHX                 LAX
# 2      DL    Delta Air Lines Inc.            SAN                 DTW
# 3      WN  Southwest Airlines Co.            MKE                 RSW
# 4      WN  Southwest Airlines Co.            MDW                 CLE
#
#    DISTANCE  SD_MONTH SCHEDULED_DEPARTURE      DEPARTURE_TIME  \
# 0      1062         4 2015-04-04 11:04:00 2015-04-04 10:59:00
# 1       370         6 2015-06-22 09:00:00 2015-06-22 10:18:00
# 2      1956        12 2015-12-27 11:35:00 2015-12-27 11:29:00
# 3      1183         5 2015-05-21 06:05:00 2015-05-21 05:58:00
# 4       307         7 2015-07-05 22:15:00 2015-07-05 22:13:00
#
#    DEPARTURE_DELAY   SCHEDULED_ARRIVAL        ARRIVAL_TIME  ARRIVAL_DELAY  \
# 0             -5.0 2015-04-04 14:00:00 2015-04-04 13:50:00          -10.0
# 1             78.0 2015-06-22 10:30:00 2015-06-22 11:33:00           63.0
# 2             -6.0 2015-12-27 18:59:00 2015-12-27 18:53:00           -6.0
# 3             -7.0 2015-05-21 10:00:00 2015-05-21 09:50:00          -10.0
# 4             -2.0 2015-07-05 00:20:00 2015-07-05 00:24:00            4.0
#
#    TAXI_OUT  WHEELS_OFF  AIR_TIME  WHEELS_ON  TAXI_IN  ELAPSED_TIME  \
# 0      13.0      1112.0     149.0     1341.0      9.0         171.0
# 1      14.0      1032.0      53.0     1125.0      8.0          75.0
# 2      29.0      1158.0     229.0     1847.0      6.0         264.0
# 3      17.0       615.0     151.0      946.0      4.0         172.0
# 4      14.0      2227.0      50.0       17.0      7.0          71.0
#
#    SCHEDULED_TIME       TOTAL_DELAY  TOTAL_DELAY_MIN  DELAY
# 0           176.0 -1 days +23:50:00            -10.0      0
# 1            90.0          01:03:00             63.0      1
# 2           264.0 -1 days +23:54:00             -6.0      0
# 3           175.0 -1 days +23:50:00            -10.0      0
# 4            65.0          00:04:00              4.0      1

# %%
plt.figure(figsize=(16,15))
ax = sns.lineplot(x='SD_MONTH', y="TOTAL_DELAY_MIN",
                  data=df)
ax.set_xlabel('Months')
ax.set_ylabel('Total Delay(min)')
# Out:
# Text(0,0.5,'Total Delay(min)')

# %% [markdown]
# __DELAY VS MONTHS__

# %%
sns.set(font_scale=2.25)
g = sns.FacetGrid(df, col='ABBR_AIRLINE',col_wrap=3,height=10)
g = g.map(sns.lineplot,'SD_MONTH',"TOTAL_DELAY_MIN")
g.fig.subplots_adjust(wspace=0.2, hspace=0.2)

# %% [markdown]
# From the graph above we can say that delay time is peaking on February, June, and December. Those months are the common vacation time which means more people are traveling so that the airports are very busy. Furthermore, all of the airlines shows similar pattern.

# %%
sns.set()
g = sns.pairplot(df[['SD_MONTH','DEPARTURE_DELAY','ARRIVAL_DELAY','ELAPSED_TIME',
         'SCHEDULED_TIME','DELAY']],hue='DELAY',palette = 'coolwarm')
g.fig.subplots_adjust(wspace=0.05, hspace=0.05)

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='SD_MONTH',data=df,
              order = df['SD_MONTH'].value_counts().index)

# %% [markdown]
# __plotting delayed flight count per month__

# %%
g = sns.countplot(x='SD_MONTH',data=df[df['DELAY']==1],
              order = df[df['DELAY']==1]['SD_MONTH'].value_counts().index)
g.set_title("Number of Delay Flights per Month")
# Out:
# Text(0.5,1,'Number of Delay Flights per Month')

# %% [markdown]
# Turns out June is the month with the most delayed flight, we can say that it is the start of summer holiday and many people travels, thus the busyness of the airports increases which causing more flights to be delayed

# %% [markdown]
# __DELAY VS DISTANCE__

# %%
plt.figure(figsize=(10,10))
g = sns.scatterplot(x='TOTAL_DELAY_MIN',y='DISTANCE',data=df)

# %% [markdown]
# The graph above shows that there is not much of a correlation within those two features but we can somewhat say that the probability of being delayed is higher when the distance is closer

# %% [markdown]
# __Heatmap to see how else the delay is correlated__

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')

# %% [markdown]
# From the graph above the strongest correlation with the delay is the month followed by air time and distance.

# %% [markdown]
# __Checking the origin airport that has the most delayed flight__

# %%
gb_origin = df.groupby('ORIGIN_AIRPORT')
origin_delay = gb_origin.DELAY.sum().sort_values(ascending=False)
origin_delay.head()
# Out:
# ORIGIN_AIRPORT
# ATL    5839
# ORD    4836
# DFW    4000
# DEN    3333
# LAX    3294
# Name: DELAY, dtype: int64

# %%
plt.subplots(figsize=(20,20))
sns.set(font_scale=2.7)
g = sns.distplot(origin_delay)
g.set_title("Distribution no. of Delays(per Airport)")
g.set_xlabel('Number of Delays occur')
# Out:
# Text(0.5,0,'Number of Delays occur')

# %%
sns.set()

# %% [markdown]
# The distribution trends towards 0-1000 number of delays per aiport but only on a couple of airports that has >3000 flight delays occurance. This means that in a particular airport(>3000) it has higher probabilty to have a delayed flight. As for other airports it cannot be concluded much since most of the 0 delays origin airport is lacking of that from that airport

# %%
df.to_csv('flights_sample_cleaned.csv',index=False)
